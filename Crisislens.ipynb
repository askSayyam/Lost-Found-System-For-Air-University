# %% [markdown]
# <a href="https://colab.research.google.com/github/askSayyam/Lost-Found-System-For-Air-University/blob/master/Crisislens.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Force delete the incorrect repository folder
# !rm -rf "Lost-Found-System-For-Air-University"
# Also remove any hidden git configurations if they exist
# !rm -rf .git

# %%
import os
print("Folder exists" if os.path.exists('/content/lost and found') else "Folder successfully removed")
# Out:
# Folder successfully removed
